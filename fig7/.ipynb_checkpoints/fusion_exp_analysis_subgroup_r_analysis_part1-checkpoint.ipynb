# %%
#### library(nsROC)
library(pROC)
library(caret)
library("PredictABEL")

auc_test <- function(final_fusion_result_csv){
    ori <- read.csv(final_fusion_result_csv, fileEncoding="gb18030")
    xin_corrected <- ori[, 1:3]
    ren <- data.frame(xin_corrected)
    names(ren) <- c("response","p1","p2")
    auc1 <- roc(response~p1,data=ren,smooth=F)
    auc2 <- roc(response~p2,data=ren,smooth=F)
    print(roc.test(auc1,auc2, paired=TRUE))

    plot(auc1,print.auc=TRUE,print.thres=TRUE,main="多组ROC曲线比较",col="blue",identity.col="blue",identity.lty=1,identity.lwd=1)
    plot(auc2,print.auc=TRUE,print.thres=TRUE,add=TRUE,col="red")
    }

nri_idi_test <- function(final_fusion_result_csv, th){
    ori <- read.csv(final_fusion_result_csv, fileEncoding="gb18030")
    corrected <- ori
    corrected <- data.frame(corrected)
    names(corrected) <- c("response","metric","fusion")
    print(head(corrected))
    preold <- corrected$metric
    prenew <- corrected$fusion
    print(reclassification(data=corrected,cOutcome = 1,predrisk1 = preold,
                     predrisk2 = prenew,cutoff = c(0,th,1)))
    }
# Out:
# Type 'citation("pROC")' for a citation.
#
#
# Attaching package: ‘pROC’
#
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
#
# Loading required package: ggplot2
#
# Loading required package: lattice

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=<45_gender=2.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -1.8023, p-value = 0.0715
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.024302174  0.001018469
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.8293218   0.8409636
#
#   response    metric    fusion
# 1        1 0.9231059 0.9200054
# 2        0 0.5248014 0.4820475
# 3        1 0.3645443 0.3467032
# 4        0 0.1714223 0.1372227
# 5        1 0.5750783 0.7072988
# 6        1 0.7072489 0.6257451
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     267       8               3
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=[45,60)_gender=2.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -1.3216, p-value = 0.1863
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.01514578  0.00294614
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.7854390   0.7915388
#
#   response    metric    fusion
# 1        0 0.3895214 0.4208400
# 2        1 0.9311663 0.9335349
# 3        1 0.4903649 0.4856319
# 4        1 0.9075983 0.9049655
# 5        0 0.5881036 0.6496816
# 6        0 0.6050442 0.6367491
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     108      18              14
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=>=60_gender=2.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -2.4035, p-value = 0.01624
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.037616904 -0.003823583
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.7570391   0.7777594
#
#   response    metric    fusion
# 1        1 0.8760832 0.8882344
# 2        1 0.9028356 0.9130285
# 3        1 0.7698885 0.7510301
# 4        1 0.8574136 0.8841281
# 5        1 0.9711697 0.9692428
# 6        1 0.9535681 0.9449799
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)       1       0               0
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=<45_gender=1.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -2.3295, p-value = 0.01983
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.023986547 -0.002066419
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.7683124   0.7813389
#
#   response     metric     fusion
# 1        1 0.68303331 0.85396729
# 2        0 0.35341222 0.33392087
# 3        1 0.67777786 0.66394723
# 4        1 0.45511428 0.58446584
# 5        0 0.01808631 0.02382938
# 6        1 0.64489703 0.74530439
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     486      20               4
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=[45,60)_gender=1.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -2.8256, p-value = 0.00472
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.018560332 -0.003357161
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.7868897   0.7978485
#
#   response    metric    fusion
# 1        1 0.3553035 0.2448435
# 2        0 0.8500911 0.7505533
# 3        0 0.5476002 0.6342517
# 4        0 0.3720100 0.5013636
# 5        0 0.7989218 0.6936628
# 6        0 0.5821056 0.6216966
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     187      33              15
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=>=60_gender=1.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -0.81299, p-value = 0.4162
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.014703762  0.006081902
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.7816701   0.7859810
#
#   response    metric    fusion
# 1        1 0.9298919 0.9345583
# 2        0 0.7600495 0.6676674
# 3        1 0.7807611 0.8094784
# 4        1 0.8607938 0.8299891
# 5        0 0.9515790 0.9597304
# 6        1 0.7880071 0.7242160
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)       5       2              29
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=>=45_gender=2.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -2.5688, p-value = 0.01021
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.013686603 -0.001839909
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.8220737   0.8298369
#
#   response    metric    fusion
# 1        0 0.3895214 0.4208400
# 2        1 0.9311663 0.9335349
# 3        1 0.4903649 0.4856319
# 4        1 0.9075983 0.9049655
# 5        1 0.8760832 0.8882344
# 6        1 0.9028356 0.9130285
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     109      18              14
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi,subgroup_var=age,desc=>=45_gender=1.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -2.7214, p-value = 0.006501
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.012436206 -0.002022753
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.8126342   0.8198637
#
#   response    metric    fusion
# 1        1 0.9298919 0.9345583
# 2        1 0.3553035 0.2448435
# 3        0 0.8500911 0.7505533
# 4        0 0.7600495 0.6676674
# 5        0 0.5476002 0.6342517
# 6        0 0.3720100 0.5013636
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     192      35              15
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi_old,subgroup_var=age,desc=<45_gender=1.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -2.8955, p-value = 0.003785
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.028146262 -0.005423328
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.7817889   0.7985736
#
#   response     metric     fusion
# 1        0 0.04260453 0.04281865
# 2        0 0.31951773 0.27442231
# 3        1 0.41609215 0.44124397
# 4        0 0.57073503 0.63708658
# 5        0 0.33915255 0.29569877
# 6        0 0.10368146 0.08943313
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     457      15               3
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi_old,subgroup_var=age,desc=>=45_gender=1.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -1.9996, p-value = 0.04554
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.0120455364 -0.0001205552
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.8101893   0.8162723
#
#   response    metric    fusion
# 1        0 0.7722188 0.8499596
# 2        1 0.7489049 0.7850194
# 3        0 0.4446298 0.4142883
# 4        1 0.8465577 0.8824452
# 5        1 0.9856164 0.9808287
# 6        1 0.8631227 0.8515614
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     174      22              11
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi_old,subgroup_var=age,desc=<45_gender=2.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -0.86938, p-value = 0.3846
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.02551187  0.00983370
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.7767987   0.7846378
#
#   response     metric     fusion
# 1        0 0.56684289 0.56771842
# 2        0 0.22028835 0.14625908
# 3        0 0.01790482 0.02449795
# 4        0 0.24256217 0.21969899
# 5        0 0.27697311 0.39165116
# 6        0 0.40315494 0.47897611
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)     230      10               4
# ...

# %%
output_dir = '/ssd/kangdang/mmc_project_2023_submission/main_exp_code/step4_exp_analysis/fig7/data/'
save_name = 'scenario_random_metric_and_fusion_mi_old,subgroup_var=age,desc=>=45_gender=2.csv'
auc_test(paste(output_dir, save_name, sep=""))
nri_idi_test(paste(output_dir, save_name, sep=""), 0.5)
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# 	DeLong's test for two correlated ROC curves
#
# data:  auc1 and auc2
# Z = -3.707, p-value = 0.0002097
# alternative hypothesis: true difference in AUC is not equal to 0
# 95 percent confidence interval:
#  -0.020192164 -0.006224923
# sample estimates:
# AUC of roc1 AUC of roc2
#   0.8163639   0.8295725
#
#   response    metric    fusion
# 1        0 0.3727379 0.3651887
# 2        0 0.8100542 0.8242664
# 3        1 0.9115530 0.9147366
# 4        0 0.8534748 0.8355508
# 5        1 0.9521287 0.9531450
# 6        1 0.9746383 0.9729645
#  _________________________________________
#
#      Reclassification table
#  _________________________________________
#
#  Outcome: absent
#
#              Updated Model
# Initial Model [0,0.5) [0.5,1]  % reclassified
#       [0,0.5)      93      25              21
# ...
